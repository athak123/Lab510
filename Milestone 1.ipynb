# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# ### Asking Questions: Attempt 1

# %%
print("Hi! We're asking questions to three people!")

x=0;
y=0;
name1 = input("So, the first person, What is your name?")
print("Hi " + name1 + " here's a few questions!")
print("Please answer in 'good' or 'bad' or enter 'bye' to quit ")
user_input[] = input("So, how is your day going, " + name1 + "?")
if user_input == 'good':
    x = x+1;
elif user_input == 'bad':
    y = y+1;
while user_input != "bye":
    ques2 = input("what is your feeling about changing countries for masters?")
    if user_input == 'good':
        x = x+1;
    elif user_input == 'bad':
        y = y+1;    
    print("thanks for answering that question, " + name1)
    ques3 = input("Ok " + name1 + " here's my final question! What do you think about your experience at UWash?" )
    if user_input == 'good':
        x=x+1;
    elif user_input == 'bad':
        y=y+1;
    break
print("thanks for answering my questions, "+ name1)

x2 = 0;
y2 = 0;
name2 = input("So, the second person, What is your name?")
print("Hi " + name2 + " here's a few questions!")
print("Please answer in 'good' or 'bad' or enter 'bye' to quit ")
user_input = input("So, how is your day going, " + name2 + "?")
if user_input == 'good':
    x2 = x2+1;
elif user_input == 'bad':
    y2 = y2+1;
while user_input != "bye":
    ques2 = input("what is your feeling about changing countries for masters?")
    if user_input == 'good':
        x2 = x2+1;
    elif user_input == 'bad':
        y2 = y2+1;    
    print("thanks for answering that question, " + name2)
    ques3 = input("Ok " + name2 + " here's my final question! What do you think about your experience at UWash?" )
    if user_input == 'good':
        x2=x2+1;
    elif user_input == 'bad':
        y2=y2+1;
    break
print("thanks for answering my questions, "+ name2)

x3 = 0;
y3 = 0;
name3 = input("So, the third person, What is your name?")
print("Hi " + name3 + " here's a few questions!")
print("Please answer in 'good' or 'bad' or enter 'bye' to quit ")
user_input = input("So, how is your day going, " + name3 + "?")
if user_input == 'good':
    x3 = x3+1;
elif user_input == 'bad':
    y3 = y3+1;
while user_input != "bye":
    ques2 = input("what is your feeling about changing countries for masters?")
    if user_input == 'good':
        x3 = x3+1;
    elif user_input == 'bad':
        y3 = y3+1;    
    print("thanks for answering that question, " + name3)
    ques3 = input("Ok " + name3 + " here's my final question! What do you think about your experience at UWash?" )
    if user_input == 'good':
        x3=x3+1;
    elif user_input == 'bad':
        y3=y3+1;
    break
print("thanks for answering my questions, "+ name3)
# Out:
# Hi! We're asking questions to three people!
# So, the first person, What is your name?Alabhya
# Hi Alabhya here's a few questions!
# Please answer in 'good' or 'bad' or enter 'bye' to quit
# So, how is your day going, Alabhya?good
# what is your feeling about changing countries for masters?good
# thanks for answering that question, Alabhya
# Ok Alabhya here's my final question! What do you think about your experience at UWash?good
# thanks for answering my questions, Alabhya
# So, the second person, What is your name?mat
# Hi mat here's a few questions!
# Please answer in 'good' or 'bad' or enter 'bye' to quit
# So, how is your day going, mat?bad
# what is your feeling about changing countries for masters?bad
# thanks for answering that question, mat
# Ok mat here's my final question! What do you think about your experience at UWash?good
# thanks for answering my questions, mat
# So, the third person, What is your name?rishabh
# Hi rishabh here's a few questions!
# ...

# %% [markdown]
# ### Making changes to logic and adding Data Structures and adding plotting features

# %%
print("Hi! We're asking questions to three people!")

x=0;
y=0;
name1 = input("So, the first person, What is your name?")
print("Hi " + name1 + " here's a few questions!")
print("Please answer in 'good' or 'bad'")
user_input = input("So, how is your day going, " + name1 + "?")
if user_input == 'good':
    x = x+1;
elif user_input == 'bad':
    y = y+1;
ques2 = input("what is your feeling about changing countries for masters?")
if ques2 == 'good':
    x = x+1;
elif ques2 == 'bad':
    y = y+1;    
print("thanks for answering that question, " + name1)
ques3 = input("Ok " + name1 + " here's my final question! What do you think about your experience at UWash?" )
if ques3 == 'good':
    x=x+1;
elif ques3 == 'bad':
    y=y+1;
print("thanks for answering my questions, "+ name1)
#taking inputs in data structure: list
user1 = [x, y];
print(user1);

x=0;
y=0;
name2 = input("So, the second person, What is your name?")
print("Hi " + name2 + " here's a few questions!")
print("Please answer in 'good' or 'bad'")
user_input = input("So, how is your day going, " + name2 + "?")
if user_input == 'good':
    x = x+1;
elif user_input == 'bad':
    y = y+1;
ques2 = input("what is your feeling about changing countries for masters?")
if ques2 == 'good':
    x = x+1;
elif ques2 == 'bad':
    y = y+1;    
print("thanks for answering that question, " + name2)
ques3 = input("Ok " + name2 + " here's my final question! What do you think about your experience at UWash?" )
if ques3 == 'good':
    x=x+1;
elif ques3 == 'bad':
    y=y+1;
print("thanks for answering my questions, "+ name2)
#taking inputs in data structure: list
user2 = [x, y];
print(user2);



x=0;
y=0;
name3 = input("So, the third person, What is your name?")
print("Hi " + name3 + " here's a few questions!")
print("Please answer in 'good' or 'bad'")
user_input = input("So, how is your day going, " + name3 + "?")
if user_input == 'good':
    x = x+1;
elif user_input == 'bad':
    y = y+1;
ques2 = input("what is your feeling about changing countries for masters?")
if ques2 == 'good':
    x = x+1;
elif ques2 == 'bad':
    y = y+1;    
print("thanks for answering that question, " + name3)
ques3 = input("Ok " + name3 + " here's my final question! What do you think about your experience at UWash?" )
if ques3 == 'good':
    x=x+1;
elif ques3 == 'bad':
    y=y+1;
print("thanks for answering my questions, "+ name3)
#taking inputs in data structure: list
user3 = [x, y];
print(user3)

import pandas as pd
import matplotlib.pyplot as plt


index = [name1, name2, name3]
df = pd.DataFrame({'good': good,
                   'bad': bad}, index=index)
ax = df.plot.bar()
# Out:
# Hi! We're asking questions to three people!
# So, the first person, What is your name?Alabhya
# Hi Alabhya here's a few questions!
# Please answer in 'good' or 'bad'
# So, how is your day going, Alabhya?good
# what is your feeling about changing countries for masters?good
# thanks for answering that question, Alabhya
# Ok Alabhya here's my final question! What do you think about your experience at UWash?good
# thanks for answering my questions, Alabhya
# [3, 0]
# So, the second person, What is your name?Bhavya
# Hi Bhavya here's a few questions!
# Please answer in 'good' or 'bad'
# So, how is your day going, Bhavya?good
# what is your feeling about changing countries for masters?bad
# thanks for answering that question, Bhavya
# Ok Bhavya here's my final question! What do you think about your experience at UWash?bad
# thanks for answering my questions, Bhavya
# [1, 2]
# So, the third person, What is your name?Saddu
# Hi Saddu here's a few questions!
# ...
